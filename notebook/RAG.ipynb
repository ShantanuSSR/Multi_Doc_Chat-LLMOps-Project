# %%
print("Hello World")
# Out:
# Hello World

# %%
! uv pip install langchain openai tiktoken rapidocr-onnxruntime python-dotenv langchain-community
# Out:
# Using Python 3.13.7 environment at: /home/shantanusingh/Downloads/Multi_doc_chat_proj/.venv
# Audited 6 packages in 4ms

# %%
import os
from dotenv import load_dotenv

load_dotenv()
print(os.getcwd())

# Only set OPENAI_API_KEY if it exists in .env file
openai_key = os.getenv("OPENAI_API_KEY")
if openai_key:
    os.environ["OPENAI_API_KEY"] = openai_key
    print("OPENAI_API_KEY loaded")
else:
    print("OPENAI_API_KEY not found in .env (optional)")
# Out:
# /home/shantanusingh/Downloads/Multi_doc_chat_proj/notebook

# %% [markdown]
# Data Ingestion

# %%
from langchain.document_loaders import TextLoader
